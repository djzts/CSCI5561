# %%
import cv2
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
from scipy import interpolate
import matlab.engine

# %%
img = cv2.imread('./pic/chi.png')  # read as matrix
plt.imshow(img)
plt.axis('off')
plt.show()
img.shape
# Out:
# (603, 748, 3)

# %%
img_ori = cv2.imread('./pic/chi_ori.png')  # read as matrix
plt.imshow(img_ori)
plt.axis('off')
plt.show()

# %%
eng = matlab.engine.start_matlab()

# %%
#str_ori = eng.string("/pic/chi_ori.png")
#str_blank = eng.string("/pic/chi.png")
#str_ori = '/pic/chi_ori.png'
#str_blank = '/pic/chi.png'
#wrapped = textwrap.wrap(str_ori)

# %%
eng.exec()
# Out:
# ---------------------------------------------------------------------------
# MatlabExecutionError                      Traceback (most recent call last)
# <ipython-input-45-66697f8e297c> in <module>
# ----> 1 eng.exec()
#
# F:\AppStore\Anaconda\lib\site-packages\matlab\engine\matlabengine.py in __call__(self, *args, **kwargs)
#      69         else:
#      70             return FutureResult(self._engine(), future, nargs, _stdout,
# ---> 71                                 _stderr, feval=True).result()
#      72
#      73     def __validate_engine(self):
#
# F:\AppStore\Anaconda\lib\site-packages\matlab\engine\futureresult.py in result(self, timeout)
#      65                 raise TypeError(pythonengine.getMessage('TimeoutCannotBeNegative'))
#      66
# ---> 67         return self.__future.result(timeout)
#      68
#      69     def cancel(self):
#
# F:\AppStore\Anaconda\lib\site-packages\matlab\engine\fevalfuture.py in result(self, timeout)
# ...

# %%
eng.quit()
